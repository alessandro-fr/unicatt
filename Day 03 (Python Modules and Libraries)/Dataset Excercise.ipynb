# %%
import numpy as np
dataset = np.genfromtxt("data.csv", delimiter=",")
dataset
# Out:
# array([[441., 163., 603., ..., 856., 933., 729.],
#        [771., 894., 615., ..., 634., 361., 804.],
#        [987., 336., 561., ..., 913., 238., 970.],
#        ...,
#        [965.,  29.,  55., ..., 196., 758., 651.],
#        [865., 914., 290., ..., 648., 373., 873.],
#        [435., 122., 253., ..., 665., 671., 114.]], shape=(40, 54))

# %%
dataset.sum()
# Out:
# np.float64(1086680.0)

# %%
column_index = 0
column_data = dataset[:, column_index]
column_data
# Out:
# array([441., 771., 987., 332., 820., 451., 855., 763., 236.,  20., 825.,
#        494., 583., 533., 897., 848., 926., 232., 854., 180., 112., 100.,
#        848., 266., 628., 115., 389., 552., 438., 273., 264., 329., 828.,
#         65., 119., 616., 183., 965., 865., 435.])
