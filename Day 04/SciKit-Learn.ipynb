# %%
import sklearn

# %%
dir(sklearn)
# Out:
# ['calibration',
#  'clone',
#  'cluster',
#  'compose',
#  'config_context',
#  'covariance',
#  'cross_decomposition',
#  'datasets',
#  'decomposition',
#  'discriminant_analysis',
#  'dummy',
#  'ensemble',
#  'exceptions',
#  'experimental',
#  'externals',
#  'feature_extraction',
#  'feature_selection',
#  'frozen',
#  'gaussian_process',
#  'get_config',
#  'impute',
#  'inspection',
#  'isotonic',
#  'kernel_approximation',
#  'kernel_ridge',
#  'linear_model',
#  'manifold',
#  'metrics',
#  'mixture',
#  'model_selection',
#  'multiclass',
#  'multioutput',
#  'naive_bayes',
#  'neighbors',
#  'neural_network',
#  'pipeline',
#  'preprocessing',
#  'random_projection',
#  'semi_supervised',
#  'set_config',
#  'show_versions',
#  'svm',
#  'tree']
