# %%
maxdistance = 30
temperature = 30.4
greet_ing = "Hot"
isRaining = False

# %%
first_value
total_amount
calc_num
data_entry
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 first_value
#       2 total_amount
#       3 calc_num
#
# NameError: name 'first_value' is not defined

# %%
float(42)
print(float(42))
# Out:
# 42.0

# %%
int(3.14159)
print(int(3.14159))
# Out:
# 3

# %%
str(99.99)
print(str(99.99))
# Out:
# 99.99

# %%
float(str(99.99))
print(float(str(99.99)))
# Out:
# 99.99
