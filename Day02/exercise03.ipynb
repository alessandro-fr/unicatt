# %%
s = "Ciao, come ti chiami?"
s
# Out:
# 'Ciao, come ti chiami?'

# %%
s = 'Ciao, come ti chiami?'
s
# Out:
# 'Ciao, come ti chiami?'

# %%
s = """
Ciao, come ti chiami?
"""
# Out:
#   Cell In[10], line 1
#     s =
#         ^
# SyntaxError: invalid syntax

# %%
name = 'Alessandro'
print(f"Ciao {name}!")
# Out:
# Ciao Alessandro!

# %%
s = 'Devo andare a mangiare'
s[0:2]
s[20:22]
print(s[:2]+s[20:22])
# Out:
# Dere

# %%
print(s[:2].lower()+s[2:20]+s[20:22].upper())
# Out:
# devo andare a mangiaRE
